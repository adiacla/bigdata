# %%
import pandas as pd
import sqlalchemy as db

# %%
# Conexión a la base de datos MySQL (expuesta en el puerto 3310)
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/db_movies_netflix_transact")
conn = engine.connect()

# %%
# 1. EXTRAER: Datos desde MySQL
query = """
SELECT 
    movie.movieID as movieID, movie.movieTitle as title, movie.releaseDate as releaseDate, 
    gender.name as gender , person.name as participantName, participant.participantRole as roleparticipant 
FROM movie 
INNER JOIN participant 
ON movie.movieID=participant.movieID
INNER JOIN person
ON person.personID = participant.personID
INNER JOIN movie_gender 
ON movie.movieID = movie_gender.movieID
INNER JOIN gender 
ON movie_gender.genderID = gender.genderID
"""

movies_data=pd.read_sql(query, con=conn) 
movies_data["movieID"]=movies_data["movieID"].astype('int')
movies_data
# Out:
#     movieID            title releaseDate     gender          participantName  \
# 0  80192187  Triple Frontier  2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother  2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run  2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant
# 0           Actor
# 1           Actor
# 2        Director

# %%
# 2. CARGAR CSV
movies_award=pd.read_csv(r"../mysql/data/Awards_movie.csv")
movies_award["movieID"]=movies_award["movieID"].astype('int')
movies_award.rename(columns={"Aware":"Award"}, inplace=True)
movies_award
# Out:
#     movieID  IdAward   Award
# 0  80210920        0   Oscar
# 1  81157374        1  Grammy
# 2  80192187        2   Oscar

# %%
# 3. TRANSFORMAR: Unión de datasets
movie_data=pd.merge(movies_data,movies_award, left_on="movieID", right_on="movieID")
movie_data
# Out:
#     movieID            title releaseDate     gender          participantName  \
# 0  80192187  Triple Frontier  2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother  2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run  2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant  IdAward   Award
# 0           Actor        2   Oscar
# 1           Actor        0   Oscar
# 2        Director        1  Grammy

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/dw_netflix")
conn = engine.connect()

# %%
movie_data = movie_data.rename(columns={'releaseDate': 'releaseMovie', 'Award': 'awardMovie'})

# %%
movie_data = movie_data.drop(columns=['IdAward'])

# %%
movie_data.head()
# Out:
#     movieID            title releaseMovie     gender          participantName  \
# 0  80192187  Triple Frontier   2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother   2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run   2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant awardMovie
# 0           Actor      Oscar
# 1           Actor      Oscar
# 2        Director     Grammy

# %%
movie_data.to_sql('dimMovie',conn,if_exists='append', index=False)
# Out:
# 3

# %%
pd.read_sql('dimMovie', con=conn)
# Out:
#     movieID            title releaseMovie     gender          participantName  \
# 0  80192187  Triple Frontier   2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother   2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run   2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant awardMovie
# 0           Actor      Oscar
# 1           Actor      Oscar
# 2        Director     Grammy

# %%
users = pd.read_csv(r"../mysql/data/users.csv", sep='|')
users
# Out:
#       idUser     username      country subscription
# 0    1002331      user123          USA      Premium
# 1    1002332  gamerGirl97       Canada        Basic
# 2    1002333   techMaster           UK      Premium
# 3    1002334    soccerFan       Brazil        Basic
# 4    1002335    travelBug    Australia      Premium
# 5    1002336   musicLover       France        Basic
# 6    1002337     foodie88        Italy      Premium
# 7    1002338   bookWorm23      Germany        Basic
# 8    1002339  fitnessJunk       Mexico      Premium
# 9   10023310    movieBuff        Japan        Basic
# 10  10023311  artAficiona        Spain      Premium
# 11  10023312   petLover99  Netherlands        Basic
# 12  10023313  fashionista   SouthKorea      Premium
# 13  10023314  codingNinja        India        Basic
# 14  10023315  natureLover       Norway      Premium
# 15  10023316  coffeeAddct     Colombia        Basic
# 16  10023317     beachBum      Bahamas      Premium
# 17  10023318  skiEnthusst  Switzerland        Basic
# 18  10023319     homeChef   NewZealand      Premium
# 19  10023320   yogiMaster     Thailand        Basic

# %%
users = users.rename(columns={'idUser': 'userID'})
users
# Out:
#       userID     username      country subscription
# 0    1002331      user123          USA      Premium
# 1    1002332  gamerGirl97       Canada        Basic
# 2    1002333   techMaster           UK      Premium
# 3    1002334    soccerFan       Brazil        Basic
# 4    1002335    travelBug    Australia      Premium
# 5    1002336   musicLover       France        Basic
# 6    1002337     foodie88        Italy      Premium
# 7    1002338   bookWorm23      Germany        Basic
# 8    1002339  fitnessJunk       Mexico      Premium
# 9   10023310    movieBuff        Japan        Basic
# 10  10023311  artAficiona        Spain      Premium
# 11  10023312   petLover99  Netherlands        Basic
# 12  10023313  fashionista   SouthKorea      Premium
# 13  10023314  codingNinja        India        Basic
# 14  10023315  natureLover       Norway      Premium
# 15  10023316  coffeeAddct     Colombia        Basic
# 16  10023317     beachBum      Bahamas      Premium
# 17  10023318  skiEnthusst  Switzerland        Basic
# 18  10023319     homeChef   NewZealand      Premium
# 19  10023320   yogiMaster     Thailand        Basic

# %%
users.to_sql('dimUser',conn,if_exists='append', index=False)
# Out:
# 20

# %% [markdown]
# Cargamos datos a la tabla de hechos

# %%
users_id=users["userID"]
movies_id=movies_data["movieID"]

# %%
watchs_data=pd.merge(users_id,movies_id, how="cross")
watchs_data
# Out:
#       userID   movieID
# 0    1002331  80192187
# 1    1002331  80210920
# 2    1002331  81157374
# 3    1002332  80192187
# 4    1002332  80210920
# 5    1002332  81157374
# 6    1002333  80192187
# 7    1002333  80210920
# 8    1002333  81157374
# 9    1002334  80192187
# 10   1002334  80210920
# 11   1002334  81157374
# 12   1002335  80192187
# 13   1002335  80210920
# 14   1002335  81157374
# 15   1002336  80192187
# 16   1002336  80210920
# 17   1002336  81157374
# 18   1002337  80192187
# 19   1002337  80210920
# 20   1002337  81157374
# 21   1002338  80192187
# 22   1002338  80210920
# 23   1002338  81157374
# 24   1002339  80192187
# 25   1002339  80210920
# 26   1002339  81157374
# 27  10023310  80192187
# 28  10023310  80210920
# 29  10023310  81157374
# 30  10023311  80192187
# 31  10023311  80210920
# 32  10023311  81157374
# 33  10023312  80192187
# 34  10023312  80210920
# 35  10023312  81157374
# 36  10023313  80192187
# 37  10023313  80210920
# 38  10023313  81157374
# 39  10023314  80192187
# 40  10023314  80210920
# 41  10023314  81157374
# 42  10023315  80192187
# 43  10023315  80210920
# 44  10023315  81157374
# 45  10023316  80192187
# 46  10023316  80210920
# 47  10023316  81157374
# 48  10023317  80192187
# 49  10023317  80210920
# 50  10023317  81157374
# 51  10023318  80192187
# 52  10023318  80210920
# 53  10023318  81157374
# 54  10023319  80192187
# 55  10023319  80210920
# 56  10023319  81157374
# 57  10023320  80192187
# 58  10023320  80210920
# 59  10023320  81157374

# %%
import random
from datetime import datetime, timedelta
import random

def gen_rating():
    # Generar un número aleatorio entre 0 y 5 con 1 solo decimal
    numero_aleatorio = round(random.uniform(0, 5), 1)
    # Mostrar el número aleatorio
    return numero_aleatorio

def gen_timestamp():
    # Generar un timestamp aleatorio dentro de un rango específico
    start_date = datetime(2024, 1, 15)
    end_date = datetime(2024, 4, 6)

    # Calcular un valor aleatorio entre start_date y end_date
    random_date = start_date + timedelta(seconds=random.randint(0, int((end_date - start_date).total_seconds())))

    # Mostrar el timestamp aleatorio
    return random_date

# %%
watchs_data["rating"]=watchs_data["movieID"].apply(lambda x: gen_rating())
watchs_data["timestamp"]=watchs_data["userID"].apply(lambda x: gen_timestamp())

# %%
watchs_data
# Out:
#       userID   movieID  rating           timestamp
# 0    1002331  80192187     0.0 2024-02-07 07:38:50
# 1    1002331  80210920     4.3 2024-03-19 00:18:55
# 2    1002331  81157374     4.9 2024-02-19 16:32:43
# 3    1002332  80192187     0.9 2024-01-24 19:22:17
# 4    1002332  80210920     3.0 2024-03-22 15:43:30
# 5    1002332  81157374     0.5 2024-02-16 05:35:51
# 6    1002333  80192187     1.3 2024-03-15 01:17:26
# 7    1002333  80210920     2.4 2024-01-31 02:35:15
# 8    1002333  81157374     3.7 2024-02-03 02:27:08
# 9    1002334  80192187     2.5 2024-03-03 00:23:41
# 10   1002334  80210920     4.8 2024-02-03 04:50:10
# 11   1002334  81157374     1.0 2024-02-08 18:23:34
# 12   1002335  80192187     0.3 2024-02-24 05:44:21
# 13   1002335  80210920     3.5 2024-03-29 07:17:20
# 14   1002335  81157374     2.4 2024-03-12 08:31:26
# 15   1002336  80192187     1.4 2024-02-27 15:52:34
# 16   1002336  80210920     4.0 2024-03-25 14:23:55
# 17   1002336  81157374     3.8 2024-03-03 06:50:26
# 18   1002337  80192187     2.7 2024-02-12 15:11:04
# 19   1002337  80210920     1.8 2024-02-11 16:09:09
# 20   1002337  81157374     1.2 2024-02-29 12:53:07
# 21   1002338  80192187     5.0 2024-02-06 19:27:46
# 22   1002338  80210920     4.0 2024-01-19 17:01:49
# 23   1002338  81157374     2.8 2024-02-13 14:26:38
# 24   1002339  80192187     0.5 2024-03-11 10:16:40
# 25   1002339  80210920     3.6 2024-02-24 04:14:52
# 26   1002339  81157374     0.9 2024-02-12 05:40:43
# 27  10023310  80192187     4.0 2024-03-16 23:09:41
# 28  10023310  80210920     0.2 2024-03-24 13:36:57
# 29  10023310  81157374     4.7 2024-02-25 05:06:00
# 30  10023311  80192187     1.0 2024-01-25 01:14:42
# 31  10023311  80210920     2.4 2024-04-05 09:40:05
# 32  10023311  81157374     4.7 2024-01-27 06:14:33
# 33  10023312  80192187     3.3 2024-03-06 01:10:12
# 34  10023312  80210920     1.2 2024-03-17 20:07:53
# 35  10023312  81157374     0.7 2024-04-01 21:55:23
# 36  10023313  80192187     2.8 2024-03-31 20:43:29
# 37  10023313  80210920     4.0 2024-01-23 04:39:26
# 38  10023313  81157374     0.3 2024-02-23 11:42:39
# 39  10023314  80192187     2.8 2024-01-17 14:44:50
# 40  10023314  80210920     2.6 2024-03-06 04:41:08
# 41  10023314  81157374     1.2 2024-02-06 08:49:41
# 42  10023315  80192187     0.0 2024-03-22 19:56:29
# 43  10023315  80210920     4.3 2024-01-18 20:06:52
# 44  10023315  81157374     0.2 2024-01-25 10:55:31
# 45  10023316  80192187     0.3 2024-01-19 05:40:17
# 46  10023316  80210920     3.3 2024-04-04 02:57:55
# 47  10023316  81157374     3.8 2024-01-17 06:39:26
# 48  10023317  80192187     4.5 2024-01-31 02:02:40
# 49  10023317  80210920     2.1 2024-02-09 16:25:34
# 50  10023317  81157374     2.6 2024-03-11 17:26:06
# 51  10023318  80192187     4.2 2024-04-01 07:51:30
# 52  10023318  80210920     0.7 2024-02-04 08:30:43
# 53  10023318  81157374     0.2 2024-03-06 07:16:24
# 54  10023319  80192187     4.7 2024-01-28 10:32:50
# 55  10023319  80210920     4.8 2024-02-12 02:55:26
# 56  10023319  81157374     4.1 2024-03-31 15:07:40
# 57  10023320  80192187     4.6 2024-03-27 01:58:45
# 58  10023320  80210920     1.8 2024-02-12 21:19:46
# 59  10023320  81157374     3.4 2024-01-16 05:17:06

# %%
# Cargamos tabla de hechos
watchs_data.to_sql("FactWatchs", conn, if_exists='append', index=False)
# Out:
# 60

# %%
# 4. GUARDAR RESULTADO
movie_data.to_csv("../mysql/data/resultados_completos.csv", index=False)
print("Archivo 'resultados_completos.csv' generado correctamente.")
# Out:
# Archivo 'resultados_completos.csv' generado correctamente.
